# %%
LoadPackage("DGMod", "0", false);
# Out:
# true

# %%
# Example Usage

# Define the factors
myGroupElement := [0, 1, 0];
myVSElement := 1;
# Out:
# [ 0, 1, 0 ]
# 1

# %%
# Create the tensor element
t := BasisElement(myGroupElement, myVSElement);
# Out:
# ([ 0, 1, 0 ]) ⊗ 1

# %%
t;
# Out:
# ([ 0, 1, 0 ]) ⊗ 1

# %%
String(t);
# Out:
# "([ 0, 1, 0 ]) ⊗ 1"

# %%
GrpElement(t);
# Out:
# [ 0, 1, 0 ]

# %%
VSpaceElement(t);
# Out:
# 1

# %% [markdown]
# ## Combinado

# %%
zeroGF := Elements(GF(4))[1];;
myVSElement:=1;;

# Create G-mod element
w1 := BasisElement(zeroGF, myVSElement);
# Out:
# (0*Z(2)) ⊗ 1

# %%
Print(w1);
# Out:
# (0*Z(2)) ⊗ 1
