# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
# Out:
# Sym( [ 1 .. 3 ] )

# %%
irreps:=IrreducibleRepresentations(G);
# Out:
# [ Pcgs([ (2,3), (1,2,3) ]) -> [ [ [ 1 ] ], [ [ 1 ] ] ],   Pcgs([ (2,3), (1,2,3) ]) -> [ [ [ -1 ] ], [ [ 1 ] ] ],   Pcgs([ (2,3), (1,2,3) ]) ->     [ [ [ 0, 1 ], [ 1, 0 ] ], [ [ E(3), 0 ], [ 0, E(3)^2 ] ] ] ]

# %%
rho:=irreps[3];
# Out:
# Pcgs([ (2,3), (1,2,3) ]) -> [ [ [ 0, 1 ], [ 1, 0 ] ], [ [ E(3), 0 ], [ 0, E(3)^2 ] ] ]

# %%
A:=rho(G.1);
# Out:
# [ [ E(3), 0 ], [ 0, E(3)^2 ] ]

# %%
B:=rho(G.2);
# Out:
# [ [ 0, E(3)^2 ], [ E(3), 0 ] ]

# %%
AtensorB:=TensorProductOfMat( A, B );
# Out:
# [ [ 0, 1, 0, 0 ], [ E(3)^2, 0, 0, 0 ], [ 0, 0, 0, E(3) ], [ 0, 0, 1, 0 ] ]

# %%
AtensorB=KroneckerProduct(A, B);
# Out:
# true
