# %%
LoadPackage( "YDCatOverkG" );
# Out:
# Syntax warning: Unbound global variable in /home/juandavid/Descargas/gap-4.13.1/pkg/YDCatOverkG/gap/basisforYDmodule.gi:119
#         base := TensorBasisForSimples( G, g, rho );;
#                 ^^^^^^^^^^^^^^^^^^^^^
# true

# %%
YDCatOverkG_Example();
