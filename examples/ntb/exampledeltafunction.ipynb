# %%
LoadPackage("YDCatOverkG", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
delta_g1:=DeltaFunctionForElementOfG(G.1, Rationals);
# Out:
# Sym( [ 1 .. 3 ] )
# function( elem2 ) ... end

# %%
delta_g1(G.1);
# Out:
# 1

# %%
delta_g1(G.2);
# Out:
# 0

# %%
delta_g1((1,3,2));
# Out:
# 0

# %%
delta_g1((1,2));
# Out:
# 0

# %%
delta_g1((1,2,3));
# Out:
# 1

# %%
delta_g1((2,3));
# Out:
# 0

# %%
G.1;
# Out:
# (1,2,3)
