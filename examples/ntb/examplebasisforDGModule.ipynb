# %%
LoadPackage("DGMod", "0", false);
# Out:
# true

# %%
G:=SymmetricGroup(3);
repsCC:=List(ConjugacyClasses(G), Representative);
g:= repsCC[2];
centralizer := Centralizer(G, g);
irrepsGamma_g  := Irr( centralizer );
chi := Irr( centralizer )[2];
rho := IrreducibleAffordingRepresentation( chi );
# Out:
# Sym( [ 1 .. 3 ] )
# [ (), (1,2), (1,2,3) ]
# (1,2)
# Sym( [ 1 .. 2 ] )
# [ Character( CharacterTable( Sym( [ 1 .. 2 ] ) ),  [ 1, 1 ] ), Character( CharacterTable( Sym( [ 1 .. 2 ] ) ), [ 1, -1 ] ) ]
# Character( CharacterTable( Sym( [ 1 .. 2 ] ) ), [ 1, -1 ] )
# [ (1,2) ] -> [ [ [ -1 ] ] ]

# %%
TensorBasisForSimpleDGMod( G, g, rho );
# Out:
# [ ( () , [ 1 ] ), ( (1,3) , [ 1 ] ), ( (1,3,2) , [ 1 ] ) ]
